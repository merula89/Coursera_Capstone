# %% [markdown]
# # Cap Stone Project Week 1

# %% [markdown]
# Hello and welcome, dear reviewer. This is the markdown cell.

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
